# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df_SDM = pd.read_csv('Web Datasets/VAC14_SDM_output.csv', index_col=False)
df_barry = pd.read_csv('Output Datasets/VAC14_ref_set_all_binary.csv', index_col=False)
print(df_SDM.head(7), '\n')
print(df_barry.head(7))
# Out:
#    PDB file Chain ID variant WT_SSE  WT_RSA(%)  WT_DEPTH (angstrom)  WT_OSP  \
# 0  1D5R.pdb        A   A121E      E        0.7                12.30   0.510
# 1  1D5R.pdb        A   A121P      E        0.7                12.30   0.510
# 2  1D5R.pdb        A   K125P      a       21.0                 4.08   0.296
# 3  1D5R.pdb        A   A126D      a       55.7                 3.10   0.230
# 4  1D5R.pdb        A   A151P      H        0.0                 7.60   0.620
# 5  1D5R.pdb        A    A34D      E        0.0                 9.70   0.550
# 6  1D5R.pdb        A    A34P      E        0.0                 9.70   0.550
#
#    WT_SS  WT_SN  WT_SO MT_SSE  MT_RSA(%)  MT_DEPTH (angstrom)  MT_OSP  MT_SS  \
# 0      0      0      0      E   0.000000                10.70   0.580      1
# 1      0      0      0      E   0.000000                10.90   0.570      0
# 2      1      0      0      a  17.299999                 4.56   0.375      0
# 3      0      0      0      a  68.700000                 3.50   0.210      0
# 4      0      0      0      H   0.000000                 6.90   0.680      0
# 5      0      0      0      E   0.000000                 8.50   0.610      1
# 6      0      0      0      E   0.000000                 9.60   0.610      0
#
#    MT_SN  MT_SO  Predicted ddg            Outcome
# 0      0      1          -2.41  Reduced stability
# 1      0      0          -3.68  Reduced stability
# 2      0      0          -0.85  Reduced stability
# 3      0      0          -0.02  Reduced stability
# 4      0      0          -4.49  Reduced stability
# 5      0      1          -2.74  Reduced stability
# 6      0      0          -3.68  Reduced stability
#
#   variant     vac14      fig4      vac7      vam3      vam7      ypt7  \
# 0   A121E  0.994536  0.775362  0.888889  0.839286  0.592593  0.638889
# 1   A121P  0.551913  0.630435  0.805556  0.464286  0.574074  0.611111
# 2   A126P  1.000000  1.007246  0.937500  1.089286  0.907407  1.388889
# 3   A126D  1.063218  1.042373  0.992701  1.555556  1.079365  1.370370
# 4   A151P  0.576923  0.805031  1.025478  0.561404  0.666667  0.980392
# 5   A309S  0.014493 -0.015748  0.072368  0.000000  0.066667 -0.321429
# 6    A34D  1.053140  1.031496  1.046053  1.234375  0.773333  1.500000
#
#       vps30     vps38       Mighell  PolyPhen ClinVar ClinVar significance  \
# 0  0.428571  0.791667  -0.417653066       1.0      no                  NaN
# 1  0.285714  0.791667   -0.49541243       1.0      no                  NaN
# 2  1.114286  1.541667  -0.578579901       1.0      no                  NaN
# 3  1.047619  2.230769  -0.256866657       1.0      no                  NaN
# 4  0.708333  0.333333  -0.805089222       1.0      no                  NaN
# 5 -0.529412 -0.142857  -0.308489513       0.0      no                  NaN
# 6  2.294118  0.800000  -0.960501593       1.0      no                  NaN
#
#   COSMIC                                         Tumor Type  Allele Frequency  \
# 0    yes                         ['Carcinoma', 'Carcinoma']               NaN
# 1    yes            ['Carcinoma', 'Carcinoma', 'Carcinoma']               NaN
# 2    yes            ['Carcinoma', 'Carcinoma', 'Carcinoma']               NaN
# 3    yes  ['Carcinoma', 'Carcinoma', 'Carcinoma', 'Carci...               NaN
# 4     no                                                NaN               NaN
# 5     no                                                NaN               NaN
# 6    yes                                      ['Carcinoma']               NaN
#
#   gnomAD  ground_truth
# 0     no           NaN
# 1     no           NaN
# 2     no           NaN
# 3     no           NaN
# 4     no           NaN
# 5     no           NaN
# 6     no           NaN

# %%
df_ref_set = df_barry.drop(['ClinVar','ClinVar significance','COSMIC',
                           'Tumor Type','Allele Frequency','gnomAD'], axis=1)

# %%
# listing frame shift and nonsense variants
print(df_ref_set[df_ref_set['variant'].str.contains('X')],'\n')
print(df_ref_set[df_ref_set['variant'].str.contains('fs')])
# Out:
#    variant     vac14      fig4      vac7      vam3      vam7      ypt7  \
# 30   E285X -0.030303 -0.068966 -0.010000 -0.258065 -0.125000  0.458333
# 49   L139X  0.897260  1.211111  1.200000  1.272727  0.588235  0.769231
# 51   L320X  0.801170  0.962617  0.842105  0.938776  0.960784  1.000000
# 72   R130X  1.061644  1.177778  1.317647  1.151515  0.862745  1.115385
# 77   R335X  1.039216  1.393617  0.979381  1.741935  1.384615  2.103448
# 91   Y178X  0.854015  0.933333  1.022989  0.885714  1.096774  1.107143
#
#        vps30     vps38       Mighell  PolyPhen  ground_truth
# 30  0.181818 -0.157895   0.082814179       NaN           NaN
# 49  1.050000  1.933333   0.049418425       NaN           NaN
# 51  0.440000  0.176471  -0.362479123       NaN           NaN
# 72  0.300000  1.333333  -0.974823136       NaN           NaN
# 77  0.800000  2.833333       #VALUE!       NaN           NaN
# 91  0.652174  0.812500  -0.478011694       NaN           NaN
#
#    variant     vac14      fig4      vac7  vam3      vam7      ypt7     vps30  \
# 10  C136fs  1.159236  1.445652  1.243697  1.75  1.190476  2.250000  2.368421
# 41  I135fs  1.211009  1.288344  1.230303  1.80  1.437500  2.413043  2.939394
#
#        vps38 Mighell  PolyPhen  ground_truth
# 10  2.192308     NaN       NaN           NaN
# 41  2.941176     NaN       NaN           NaN

# %%
# dropping f/s and X variants
df_ref_set.drop([30,49,51,72,77,91,10,41], axis=0, inplace=True)

# %%
df_all = df_ref_set.merge(df_SDM, on='variant', how='left')

# %%
print(len(df_all))
# Out:
# 90

# %%
df_all[df_all['variant'] == 'A79T']
# Out:
#   variant     vac14      fig4      vac7      vam3      vam7     ypt7  \
# 8    A79T  0.009091 -0.018987  0.028409  0.034483 -0.144578 -0.03125
#
#       vps30  vps38      Mighell  ...  WT_SO  MT_SSE MT_RSA(%)  \
# 8 -0.285714   -0.3  0.054034306  ...    0.0       a      80.2
#
#   MT_DEPTH (angstrom) MT_OSP  MT_SS  MT_SN  MT_SO  Predicted ddg  \
# 8                 3.2   0.19    0.0    0.0    0.0          -0.11
#
#              Outcome
# 8  Reduced stability
#
# [1 rows x 30 columns]

# %%
df_all = df_all.drop(df_all[['PDB file','Chain ID', 'WT_SSE', 'MT_SSE', 'Outcome']], axis=1)

# %%
df_all[df_all['variant'] == 'A79T']
# Out:
#   variant     vac14      fig4      vac7      vam3      vam7     ypt7  \
# 8    A79T  0.009091 -0.018987  0.028409  0.034483 -0.144578 -0.03125
#
#       vps30  vps38      Mighell  ...  WT_SS  WT_SN  WT_SO  MT_RSA(%)  \
# 8 -0.285714   -0.3  0.054034306  ...    0.0    0.0    0.0       80.2
#
#    MT_DEPTH (angstrom)  MT_OSP  MT_SS  MT_SN  MT_SO  Predicted ddg
# 8                  3.2    0.19    0.0    0.0    0.0          -0.11
#
# [1 rows x 25 columns]

# %% [markdown]
# # setting up training data

# %%
training_df = df_all.dropna().copy()

# %%
training_df.reset_index(drop=True)
# Out:
#    variant     vac14      fig4      vac7      vam3      vam7      ypt7  \
# 0     A79T  0.009091 -0.018987  0.028409  0.034483 -0.144578 -0.031250
# 1    C124S  1.040698  1.191304  1.117647  2.069767  1.101695  3.230769
# 2    C211W  0.176471  0.221154  0.403846  0.000000  0.324324  0.307692
# 3    D107V  0.968153  1.336957  1.100840  1.431818  0.952381  2.312500
# 4    D252G  0.581699  0.957447  1.061856  1.806452  0.769231  1.965517
# 5    D268E  0.019324  0.023622  0.039474  0.046875 -0.066667  0.750000
# 6    F241S  0.660131  1.191489  1.247423  1.612903  1.134615  1.896552
# 7     F56C  0.647059  0.884615  1.033898  1.166667  1.320755  1.612903
# 8    G127R  0.971264  0.957627  1.007299  1.250000  1.015873  1.444444
# 9    G129E  1.301471  1.288462  1.457627  2.000000  1.886792  1.677419
# 10   G129R  1.055046  1.092025  1.339394  1.428571  1.487500  1.717391
# 11   G132D  0.994186  1.034783  1.075630  1.139535  0.966102  1.230769
# 12    G44D  0.931818  1.044304  1.056818  0.965517  0.855422  1.062500
# 13   H123Y  0.949541  1.239264  1.369697  1.742857  1.475000  2.978261
# 14    H93Q  0.272059  0.105769  0.186441  1.111111  0.471698  0.967742
# 15    H93R -0.191781 -0.522222 -0.658824 -0.393939 -0.372549 -0.923077
# 16    H93Y  0.156863  0.317308  0.490385  0.161290  0.621622  0.256410
# 17   I101T  0.738854  1.206522  1.260504  1.659091  1.253968  2.437500
# 18   I135T  0.205882  0.384615  0.542373  0.583333  0.320755  0.580645
# 19   I135V  0.160550  0.355828  0.412121  0.785714  0.562500  1.456522
# 20   M134I  0.712418  0.932692  1.201923  1.258065  1.540541  1.153846
# 21   M134T  0.893939  1.080460  0.830000  1.129032  0.812500  1.041667
# 22   M198I  0.036364 -0.018987  0.000000  0.120690 -0.060241  0.203125
# 23   N228S  0.027273  0.031646  0.039773 -0.155172  0.108434 -0.062500
# 24   N262S -0.045455 -0.170886 -0.204545 -0.137931 -0.156627 -0.171875
# 25   P246L  0.211679  0.588889  0.781609  0.285714  0.516129  0.464286
# 26   R130L  1.075342  1.333333  1.494118  1.818182  1.235294  2.923077
# 27   R130Q  1.022989  0.983051  1.000000  1.277778  0.936508  1.111111
# 28    R14G  0.781022  0.966667  1.172414  0.771429  1.129032  0.857143
# 29    R15S  0.742424  0.931034  1.030000  1.000000  0.843750  0.625000
# 30   R173H  0.248175  0.655556  0.827586  0.285714  0.290323  0.035714
# 31   R173P  1.004808  0.805031  0.929936  0.842105  0.706667  0.607843
# 32   T131I  0.912791  1.043478  1.000000  1.302326  1.084746  1.461538
# 33   V255A  0.457516  0.755319  0.927835  1.709677  1.365385  1.241379
# 34   Y180H  1.198529  1.182692  1.118644  1.750000  1.301887  1.806452
# 35    Y27C  0.742424  0.908046  1.010000  1.032258  1.062500  1.291667
# 36    Y68H  0.910828  1.217391  1.092437  0.727273  0.714286  0.906250
# 37    Y68N  1.286765  1.038462  1.076271  1.888889  1.377358  1.935484
#
#        vps30     vps38       Mighell  ...  WT_SS  WT_SN  WT_SO  MT_RSA(%)  \
# 0  -0.285714 -0.300000   0.054034306  ...    0.0    0.0    0.0       80.2
# 1   1.500000  1.285714  -1.223910727  ...    1.0    1.0    1.0        4.3
# 2   0.360000  0.500000  -0.250662359  ...    0.0    0.0    1.0        0.0
# 3   2.842105  2.192308  -0.712965385  ...    1.0    0.0    0.0       41.6
# 4   1.866667  2.388889  -0.522853504  ...    1.0    1.0    0.0       27.2
# 5  -0.058824  0.085714   0.056335824  ...    0.0    0.0    0.0       51.0
# 6   1.533333  1.833333  -0.599858557  ...    0.0    0.0    0.0       18.1
# 7   4.857143  4.833333  -0.240570479  ...    0.0    0.0    0.0        0.5
# 8   0.904762  2.538462   -0.55825153  ...    0.0    0.0    0.0        0.0
# 9   5.642857  6.250000  -1.352440879  ...    0.0    0.0    0.0        4.5
# 10  2.333333  2.117647  -0.369397125  ...    0.0    0.0    0.0       23.3
# 11  0.416667  0.821429  -0.840472238  ...    0.0    0.0    0.0        0.0
# 12  1.047619  0.700000  -0.770082865  ...    0.0    0.0    0.0       98.9
# 13  3.757576  3.352941  -1.136100361  ...    1.0    0.0    0.0        0.0
# 14  2.071429  1.666667   -0.02280045  ...    0.0    0.0    0.0       78.0
# 15 -1.800000 -2.266667   0.007569453  ...    0.0    0.0    0.0       79.1
# 16  1.040000  0.727273  -0.615014941  ...    0.0    0.0    0.0       58.7
# 17  3.473684  2.769231  -0.777155334  ...    0.0    0.0    0.0        2.8
# 18  1.214286  1.666667  -0.207048792  ...    0.0    0.0    0.0        1.1
# 19  1.484848  2.264706  -0.018392296  ...    0.0    0.0    0.0        0.5
# 20  0.720000  1.090909  -0.427779605  ...    0.0    0.0    0.0        0.0
# 21  0.000000  1.000000  -0.368669915  ...    0.0    0.0    0.0        7.3
# 22 -0.476190 -0.066667  -0.060583007  ...    0.0    0.0    0.0        0.0
# 23  0.380952  0.133333  -0.095585025  ...    0.0    0.0    0.0      105.2
# 24 -0.333333 -0.633333  -0.052001162  ...    0.0    0.0    0.0       85.1
# 25  0.217391  0.125000  -0.405413153  ...    0.0    0.0    0.0       55.1
# 26  3.000000  3.200000  -0.774535119  ...    0.0    0.0    1.0       11.6
# 27  1.238095  1.692308  -0.510041028  ...    0.0    0.0    1.0        8.0
# 28  0.956522  1.500000  -0.177695061  ...    0.0    0.0    0.0       66.3
# 29  1.181818  0.631579  -0.645275196  ...    0.0    0.0    1.0       52.3
# 30 -0.086957  0.375000  -0.334541432  ...    0.0    0.0    1.0       34.9
# 31  0.833333  0.424242  -0.993846449  ...    0.0    0.0    1.0       44.4
# 32  0.583333  0.857143  -0.477832258  ...    1.0    0.0    0.0        0.0
# 33  3.000000  2.277778  -0.324934299  ...    0.0    0.0    0.0        1.2
# 34  2.928571  4.333333   0.084011189  ...    0.0    0.0    0.0       54.7
# 35  0.727273  1.315789  -0.412139491  ...    0.0    0.0    0.0       33.7
# 36  1.526316  1.230769  -0.840853189  ...    1.0    0.0    0.0        0.0
# 37  3.500000  4.833333  -1.230020146  ...    1.0    0.0    0.0        3.7
#
#     MT_DEPTH (angstrom)  MT_OSP  MT_SS  MT_SN  MT_SO  Predicted ddg
# 0                   3.2    0.19    0.0    0.0    0.0          -0.11
# 1                   7.3    0.54    1.0    1.0    0.0          -1.44
# 2                   7.6    0.69    1.0    0.0    0.0          -1.53
# 3                   3.8    0.43    0.0    0.0    0.0           0.72
# 4                   5.5    0.31    0.0    0.0    0.0          -0.72
# 5                   3.5    0.28    0.0    0.0    0.0           1.16
# 6                   6.9    0.40    0.0    0.0    0.0          -2.96
# 7                   6.6    0.48    0.0    0.0    0.0          -0.93
# 8                   8.3    0.74    1.0    0.0    1.0          -2.85
# 9                   7.3    0.61    1.0    1.0    0.0           1.95
# 10                  4.7    0.37    1.0    0.0    0.0           1.24
# 11                 10.4    0.72    1.0    0.0    0.0          -2.62
# 12                  3.3    0.12    0.0    0.0    0.0          -3.05
# 13                 11.4    0.64    1.0    1.0    1.0          -0.11
# 14                  3.5    0.21    0.0    0.0    0.0          -0.15
# 15                  3.4    0.16    0.0    0.0    0.0          -0.14
# 16                  3.6    0.22    0.0    0.0    0.0           0.32
# 17                  8.4    0.44    0.0    0.0    1.0          -3.12
# 18                 10.6    0.48    0.0    0.0    0.0          -2.54
# 19                 11.3    0.50    0.0    0.0    0.0          -2.56
# 20                 11.4    0.56    0.0    0.0    0.0          -0.29
# 21                 11.6    0.52    0.0    0.0    0.0          -2.28
# 22                 11.0    0.52    0.0    0.0    0.0           0.85
# 23                  3.0    0.15    0.0    0.0    0.0           0.36
# 24                  3.3    0.19    0.0    0.0    0.0           0.36
# 25                  3.7    0.28    0.0    0.0    0.0           2.33
# 26                  6.8    0.49    0.0    0.0    0.0          -1.19
# 27                  6.9    0.47    0.0    0.0    1.0          -1.98
# 28                  3.5    0.16    0.0    0.0    0.0           0.00
# 29                  3.6    0.37    0.0    0.0    0.0          -0.92
# 30                  4.3    0.34    0.0    0.0    1.0          -1.48
# 31                  3.8    0.38    0.0    0.0    0.0          -3.52
# 32                  9.1    0.64    0.0    0.0    0.0           0.95
# 33                 10.3    0.41    0.0    0.0    0.0          -2.85
# 34                  3.6    0.33    0.0    0.0    1.0          -0.34
# 35                  3.6    0.34    0.0    0.0    0.0          -0.06
# 36                  8.2    0.48    0.0    0.0    0.0          -1.42
# 37                  8.7    0.45    0.0    0.0    0.0          -2.66
#
# [38 rows x 25 columns]

# %%
# how many variants with ground_truth=0?
print(training_df[training_df[['ground_truth']] == 0].count()['ground_truth'])
print()
# how many entries have ground truth?
print(training_df.count()['ground_truth'])
# Out:
# 8
#
# 38

# %%
y = training_df[['ground_truth']]
print(y.shape)
# Out:
# (38, 1)

# %%
def do_sentinel(sen):
    X = training_df.drop(['variant','ground_truth'], axis=1)
    X.drop(X.iloc[:,:10], axis=1, inplace=True)
    X.insert(0, sen, training_df[sen])
    return X

# %%
#X = do_sentinel('vac14')
X = do_sentinel('fig4')
#X = do_sentinel('vac7')
#X = do_sentinel('vam3')
#X = do_sentinel('vam7')
#X = do_sentinel('ypt7')
#X = do_sentinel('vps30')
#X = do_sentinel('vps38')
#X = do_sentinel('Mighell')
#X = do_sentinel('PolyPhen')

# %%
X.head()
# Out:
#         fig4  WT_RSA(%)  WT_DEPTH (angstrom)  WT_OSP  WT_SS  WT_SN  WT_SO  \
# 8  -0.018987       86.3                  3.1    0.19    0.0    0.0    0.0
# 9   1.191304        4.3                  6.7    0.52    1.0    1.0    1.0
# 10  0.221154        0.3                  7.3    0.50    0.0    0.0    1.0
# 12  1.336957       32.0                  3.8    0.44    1.0    0.0    0.0
# 14  0.957447        8.6                  5.7    0.39    1.0    1.0    0.0
#
#     MT_RSA(%)  MT_DEPTH (angstrom)  MT_OSP  MT_SS  MT_SN  MT_SO  Predicted ddg
# 8        80.2                  3.2    0.19    0.0    0.0    0.0          -0.11
# 9         4.3                  7.3    0.54    1.0    1.0    0.0          -1.44
# 10        0.0                  7.6    0.69    1.0    0.0    0.0          -1.53
# 12       41.6                  3.8    0.43    0.0    0.0    0.0           0.72
# 14       27.2                  5.5    0.31    0.0    0.0    0.0          -0.72

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=0)

# %% [markdown]
# # Apply logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
LR = LogisticRegression(random_state=0, solver='liblinear').fit(
    X_train, y_train.values.ravel())

# %%
LR_pred = LR.predict(X_test)

# %%
print(LR_pred)
# Out:
# [0. 1. 1. 0. 1. 1. 1. 1. 0. 1. 1. 1.]

# %%
print('The accuracy is {0:0.3f}'.format(accuracy_score(y_test, LR_pred)))
# Out:
# The accuracy is 0.833

# %%
LR_kfold_scores = cross_val_score(LR, X, y.values.ravel(), cv=5)
print(LR_kfold_scores, '\n')
print('The average cross-validation score is {0:0.3f}'.format(np.mean(LR_kfold_scores)))
# Out:
# [0.75       0.75       0.75       0.71428571 0.85714286]
#
# The average cross-validation score is 0.764

# %%
print(classification_report(y_test, LR_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.33      1.00      0.50         1
#          1.0       1.00      0.82      0.90        11
#
#    micro avg       0.83      0.83      0.83        12
#    macro avg       0.67      0.91      0.70        12
# weighted avg       0.94      0.83      0.87        12
